# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from src.data import ImageCSVData, TrachomaDataModule
from src.transforms import build_train_transforms, build_eval_transforms

# %%
data_df = pd.read_csv('../data/all_metadata.csv')

# %%
train_transforms = build_train_transforms(img_size=520)
eval_transforms = build_eval_transforms(img_size=520)

# %%
data_module = TrachomaDataModule(df=data_df, train_tfms=train_transforms, eval_tfms=eval_transforms)
